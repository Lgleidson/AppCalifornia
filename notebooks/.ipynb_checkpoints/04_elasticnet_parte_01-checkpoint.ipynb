# %% [markdown]
# # Grid search
#
# O `GridSearchCV` do Scikit-Learn é uma ferramenta utilizada para otimizar hiperparâmetros de modelos de machine learning. Hiperparâmetros são parâmetros do modelo que não são aprendidos diretamente pelos algoritmos de aprendizado, mas que precisam ser definidos antes do processo de treino. Exemplos comuns incluem a profundidade máxima de uma árvore de decisão ou a taxa de aprendizado de um modelo de gradient boosting. Encontrar os valores corretos desses hiperparâmetros pode impactar significativamente a performance do modelo.
#
# O `GridSearchCV` automatiza esse processo, testando exaustivamente todas as combinações possíveis de valores fornecidos para os hiperparâmetros, criando uma grade (ou "grid") de opções. Ele faz isso utilizando validação cruzada (cross-validation), o que significa que o conjunto de dados é dividido em múltiplas partes (folds) e o desempenho do modelo é avaliado em diferentes subdivisões. Dessa forma, o processo minimiza o risco de overfitting e garante que o modelo generalize melhor para dados não vistos.
#
# Após testar todas as combinações, o `GridSearchCV` retorna o conjunto de hiperparâmetros que apresentou o melhor desempenho com base na métrica de avaliação definida, como acurácia, F1-score, entre outros.
#
# Em resumo, o `GridSearchCV` é uma abordagem sistemática e eficiente para encontrar os melhores hiperparâmetros de um modelo, evitando o trabalho manual de testar diferentes combinações e proporcionando resultados mais robustos.
#
# https://scikit-learn.org/stable/modules/grid_search.html#grid-search
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.ElasticNet.html

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet, Lasso, LinearRegression, Ridge
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PowerTransformer,
    StandardScaler,
    QuantileTransformer,
)

from src.auxiliares import dataframe_coeficientes
from src.config import DADOS_DIABETES_CATEGORIZADOS
from src.graficos import plot_comparar_metricas_modelos, plot_coeficientes
from src.modelos import RANDOM_STATE
#from src.modelos import grid_search_cv_regressor, organiza_resultados, treinar_e_validar_modelo_regressao
from src.modelos import grid_search_cv_regressor, organiza_resultados, treinar_e_validar_modelo_regressao


sns.set_theme(palette="bright")

# %%
df = pd.read_parquet(DADOS_DIABETES_CATEGORIZADOS)

df.head()
# Out:
#    idade  sexo        imc  pressao_media  colesterol_total         ldl   hdl  \
# 0     59     2  32.099998          101.0               157   93.199997  38.0
# 1     48     1  21.600000           87.0               183  103.199997  70.0
# 2     72     2  30.500000           93.0               156   93.599998  41.0
# 3     24     1  25.299999           84.0               198  131.399994  40.0
# 4     50     1  23.000000          101.0               192  125.400002  52.0
#
#    triglicerides  glicose  target colesterol_hdl_cat
# 0         4.8598       87     151                4-5
# 1         3.8918       69      75                2-3
# 2         4.6728       85     141                4-5
# 3         4.8903       89     206                4-5
# 4         4.2905       80     135                4-5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   idade               442 non-null    int8
#  1   sexo                442 non-null    int8
#  2   imc                 442 non-null    float32
#  3   pressao_media       442 non-null    float32
#  4   colesterol_total    442 non-null    int16
#  5   ldl                 442 non-null    float32
#  6   hdl                 442 non-null    float32
#  7   triglicerides       442 non-null    float32
#  8   glicose             442 non-null    int8
#  9   target              442 non-null    int16
#  10  colesterol_hdl_cat  442 non-null    category
# dtypes: category(1), float32(5), int16(2), int8(3)
# memory usage: 12.3 KB

# %%
X = df.drop(columns="target")
y = df["target"]

# %%
colunas_power_transform = ["imc", "ldl", "hdl", "colesterol_total"]

coluna_target = ["target"]

coluna_ordinal_encoder = ["colesterol_hdl_cat"]

coluna_one_hot_encoder = ["sexo"]

colunas_standard_scaler = [
    coluna
    for coluna in df.columns
    if coluna not in colunas_power_transform + coluna_target + coluna_ordinal_encoder + coluna_one_hot_encoder
]

colunas_standard_scaler
# Out:
# ['idade', 'pressao_media', 'triglicerides', 'glicose']

# %%
categorias_ordinal_encoder = [
    ["2-3", "4-5", "6+"],
]

# %%
preprocessamento_categoricas = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories=categorias_ordinal_encoder), coluna_ordinal_encoder),
        ("one_hot_encoder", OneHotEncoder(drop="if_binary"), coluna_one_hot_encoder),
    ],
    remainder="passthrough",
)

preprocessamento_simples = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories=categorias_ordinal_encoder), coluna_ordinal_encoder),
        ("one_hot_encoder", OneHotEncoder(drop="if_binary"), coluna_one_hot_encoder),
        ("standard_scaler", StandardScaler(), X.columns.difference(coluna_ordinal_encoder + coluna_one_hot_encoder)),
    ],
    remainder="passthrough",
)

preprocessamento_completo = ColumnTransformer(
    [
        ("power_transform", PowerTransformer(method="box-cox"), colunas_power_transform),
        ("standard_scaler", StandardScaler(), colunas_standard_scaler),
        ("ordinal_encoder", OrdinalEncoder(categories=categorias_ordinal_encoder), coluna_ordinal_encoder),
        ("one_hot_encoder", OneHotEncoder(drop="if_binary"), coluna_one_hot_encoder),
    ]
)

target_transformer = QuantileTransformer(n_quantiles=20, output_distribution="normal")

# %%
elasticnet_regressor = ElasticNet()

# %%
param_grid = {
    "regressor__reg__alpha": [1E-2, 5E-2, 0.1, 1.0, 5.0, 10],
    "regressor__reg__l1_ratio": [0.1, 0.25, 0.5, 0.75, 0.9],
    "regressor__preprocessor": [preprocessamento_categoricas, preprocessamento_simples, preprocessamento_completo],
    "transformer": [target_transformer, None]
}

# %%
grid_search = grid_search_cv_regressor(
    regressor=elasticnet_regressor,
    param_grid=param_grid,
    preprocessor=preprocessamento_categoricas,
    target_transformer=target_transformer,
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(remainder='passthrough',
#                                                                                                transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(categories=[['2-3',
#                                                                                                                                           '4-5',
#                                                                                                                                           '6+']]),
#                                                                                                               ['colesterol_hdl_cat']),
#                                                                                                              ('one_hot_encoder',
#                                                                                                               OneHotEncoder(drop='if_binary'),
#                                                                                                               ['sexo'])]...
#                                                                                       OneHotEncoder(drop='if_binary'),
#                                                                                       ['sexo'])])],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 1.0, 5.0,
#                                                    10],
#                          'regressor__reg__l1_ratio': [0.1, 0.25, 0.5, 0.75,
#                                                       0.9],
#                          'transformer': [QuantileTransformer(n_quantiles=20,
#                                                              output_distribution='normal'),
#                                          None]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(remainder='passthrough',
#                                                                                                transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(categories=[['2-3',
#                                                                                                                                           '4-5',
#                                                                                                                                           '6+']]),
#                                                                                                               ['colesterol_hdl_cat']),
#                                                                                                              ('one_hot_encoder',
#                                                                                                               OneHotEncoder(drop='if_binary'),
#                                                                                                               ['sexo'])]...
#                                                                                       OneHotEncoder(drop='if_binary'),
#                                                                                       ['sexo'])])],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 1.0, 5.0,
#                                                    10],
#                          'regressor__reg__l1_ratio': [0.1, 0.25, 0.5, 0.75,
#                                                       0.9],
#                          'transformer': [QuantileTransformer(n_quantiles=20,
#                                                              output_distribution='normal'),
#                                          None]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'regressor__preprocessor': ColumnTransformer(remainder='passthrough',
#                    transformers=[('ordinal_encoder',
#                                   OrdinalEncoder(categories=[['2-3', '4-5',
#                                                               '6+']]),
#                                   ['colesterol_hdl_cat']),
#                                  ('one_hot_encoder',
#                                   OneHotEncoder(drop='if_binary'), ['sexo']),
#                                  ('standard_scaler', StandardScaler(),
#                                   Index(['colesterol_total', 'glicose', 'hdl', 'idade', 'imc', 'ldl',
#         'pressao_media', 'triglicerides'],
#        dtype='object'))]),
#  'regressor__reg__alpha': 0.01,
#  'regressor__reg__l1_ratio': 0.9,
#  'transformer': None}

# %%
grid_search.best_score_
# Out:
# -54.64479786394469

# %%
grid_search.best_estimator_
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         transformers=[('ordinal_encoder',
#                                                                                        OrdinalEncoder(categories=[['2-3',
#                                                                                                                    '4-5',
#                                                                                                                    '6+']]),
#                                                                                        ['colesterol_hdl_cat']),
#                                                                                       ('one_hot_encoder',
#                                                                                        OneHotEncoder(drop='if_binary'),
#                                                                                        ['sexo']),
#                                                                                       ('standard_scaler',
#                                                                                        StandardScaler(),
#                                                                                        Index(['colesterol_total', 'glicose', 'hdl', 'idade', 'imc', 'ldl',
#        'pressao_media', 'triglicerides'],
#       dtype='object'))])),
#                                                      ('reg',
#                                                       ElasticNet(alpha=0.01,
#                                                                  l1_ratio=0.9))]))

# %%
print(*grid_search.cv_results_.keys(), sep="\n")
# Out:
# mean_fit_time
# std_fit_time
# mean_score_time
# std_score_time
# param_regressor__preprocessor
# param_regressor__reg__alpha
# param_regressor__reg__l1_ratio
# param_transformer
# params
# split0_test_r2
# split1_test_r2
# split2_test_r2
# split3_test_r2
# split4_test_r2
# mean_test_r2
# std_test_r2
# rank_test_r2
# split0_test_neg_mean_absolute_error
# split1_test_neg_mean_absolute_error
# split2_test_neg_mean_absolute_error
# split3_test_neg_mean_absolute_error
# split4_test_neg_mean_absolute_error
# mean_test_neg_mean_absolute_error
# std_test_neg_mean_absolute_error
# rank_test_neg_mean_absolute_error
# split0_test_neg_root_mean_squared_error
# split1_test_neg_root_mean_squared_error
# split2_test_neg_root_mean_squared_error
# split3_test_neg_root_mean_squared_error
# split4_test_neg_root_mean_squared_error
# mean_test_neg_root_mean_squared_error
# std_test_neg_root_mean_squared_error
# rank_test_neg_root_mean_squared_error

# %%
max(grid_search.cv_results_["mean_test_neg_root_mean_squared_error"])
# Out:
# -54.64479786394469

# %%
grid_search.best_estimator_
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         transformers=[('ordinal_encoder',
#                                                                                        OrdinalEncoder(categories=[['2-3',
#                                                                                                                    '4-5',
#                                                                                                                    '6+']]),
#                                                                                        ['colesterol_hdl_cat']),
#                                                                                       ('one_hot_encoder',
#                                                                                        OneHotEncoder(drop='if_binary'),
#                                                                                        ['sexo']),
#                                                                                       ('standard_scaler',
#                                                                                        StandardScaler(),
#                                                                                        Index(['colesterol_total', 'glicose', 'hdl', 'idade', 'imc', 'ldl',
#        'pressao_media', 'triglicerides'],
#       dtype='object'))])),
#                                                      ('reg',
#                                                       ElasticNet(alpha=0.01,
#                                                                  l1_ratio=0.9))]))

# %%
grid_search.best_estimator_.regressor_["preprocessor"]
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('ordinal_encoder',
#                                  OrdinalEncoder(categories=[['2-3', '4-5',
#                                                              '6+']]),
#                                  ['colesterol_hdl_cat']),
#                                 ('one_hot_encoder',
#                                  OneHotEncoder(drop='if_binary'), ['sexo']),
#                                 ('standard_scaler', StandardScaler(),
#                                  Index(['colesterol_total', 'glicose', 'hdl', 'idade', 'imc', 'ldl',
#        'pressao_media', 'triglicerides'],
#       dtype='object'))])

# %%
grid_search.best_estimator_.regressor_["reg"]
# Out:
# ElasticNet(alpha=0.01, l1_ratio=0.9)

# %%
grid_search.best_estimator_.transformer_
# Out:
# FunctionTransformer(validate=True)

# %%
grid_search.best_estimator_.regressor_["reg"].coef_
# Out:
# array([  8.66056884, -22.80889645, -29.81744129,   3.46759667,
#          0.22102084,  -0.58293656,  24.73142429,  17.48861026,
#         15.14820743,  33.13283455])

# %%
grid_search.best_estimator_.regressor_["reg"].intercept_
# Out:
# 156.3102546059806

# %%
grid_search.best_estimator_.regressor_["preprocessor"].get_feature_names_out()
# Out:
# array(['ordinal_encoder__colesterol_hdl_cat', 'one_hot_encoder__sexo_2',
#        'standard_scaler__colesterol_total', 'standard_scaler__glicose',
#        'standard_scaler__hdl', 'standard_scaler__idade',
#        'standard_scaler__imc', 'standard_scaler__ldl',
#        'standard_scaler__pressao_media', 'standard_scaler__triglicerides'],
#       dtype=object)

# %%
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_["reg"].coef_,
    grid_search.best_estimator_.regressor_["preprocessor"].get_feature_names_out()
)

coefs
# Out:
#                                      coeficiente
# standard_scaler__colesterol_total     -29.817441
# one_hot_encoder__sexo_2               -22.808896
# standard_scaler__idade                 -0.582937
# standard_scaler__hdl                    0.221021
# standard_scaler__glicose                3.467597
# ordinal_encoder__colesterol_hdl_cat     8.660569
# standard_scaler__pressao_media         15.148207
# standard_scaler__ldl                   17.488610
# standard_scaler__imc                   24.731424
# standard_scaler__triglicerides         33.132835

# %%
plot_coeficientes(coefs, "ElasticNet com StdSc, OE, OHE")

# %%
df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df_resultados = organiza_resultados(resultados)
#       3 df_resultados
#
# NameError: name 'resultados' is not defined

# %%
regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    
    "LinearRegression_pre_simples": {
        "preprocessor": preprocessamento_simples,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "ElasticNet_grid_search": {
        "preprocessor": grid_search.best_estimator_.regressor_["preprocessor"],
        "regressor": grid_search.best_estimator_.regressor_["reg"],
        "target_transformer": None,
    },
}

# %%
resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

resultados
# Out:
# {'DummyRegressor': {'fit_time': array([0.00278473, 0.00104284, 0.00100017, 0.00104785, 0.002002  ]),
#   'score_time': array([0.00200081, 0.00195599, 0.00200081, 0.00195241, 0.0009954 ]),
#   'test_r2': array([-0.01196298, -0.02697753, -0.01530397, -0.00021233, -0.04231598]),
#   'test_neg_mean_absolute_error': array([-64.00646147, -70.57793551, -59.82954545, -70.05392912,
#          -65.42565485]),
#   'test_neg_root_mean_squared_error': array([-73.22249284, -80.04318688, -74.33859714, -82.04745226,
#          -76.3152967 ])},
#  'LinearRegression_pre_simples': {'fit_time': array([0.00209904, 0.01019907, 0.00873208, 0.00900316, 0.00900006]),
#   'score_time': array([0.01821065, 0.00592661, 0.00600481, 0.0059967 , 0.00573874]),
#   'test_r2': array([0.45229974, 0.57370343, 0.40683321, 0.58812556, 0.39131907]),
#   'test_neg_mean_absolute_error': array([-42.98079751, -41.53071355, -46.70245302, -41.89567184,
#          -47.42385601]),
#   'test_neg_root_mean_squared_error': array([-53.86834947, -51.57031955, -56.82045812, -52.6503691 ,
#          -58.31855408])},
#  'ElasticNet_grid_search': {'fit_time': array([0.01020694, 0.00999904, 0.00999928, 0.00951743, 0.00976539]),
#   'score_time': array([0.00510502, 0.00615001, 0.00458813, 0.00601721, 0.00601196]),
#   'test_r2': array([0.45294977, 0.5730375 , 0.40609918, 0.58772983, 0.3928374 ]),
#   'test_neg_mean_absolute_error': array([-42.98745688, -41.54709429, -46.75480704, -41.90898806,
#          -47.33524262]),
#   'test_neg_root_mean_squared_error': array([-53.8363735 , -51.61058344, -56.85560464, -52.67565587,
#          -58.24577187])}}

# %%
df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                            model  fit_time score_time   test_r2  \
# 0                 DummyRegressor  0.002785   0.002001 -0.011963
# 1                 DummyRegressor  0.001043   0.001956 -0.026978
# 2                 DummyRegressor     0.001   0.002001 -0.015304
# 3                 DummyRegressor  0.001048   0.001952 -0.000212
# 4                 DummyRegressor  0.002002   0.000995 -0.042316
# 5   LinearRegression_pre_simples  0.002099   0.018211    0.4523
# 6   LinearRegression_pre_simples  0.010199   0.005927  0.573703
# 7   LinearRegression_pre_simples  0.008732   0.006005  0.406833
# 8   LinearRegression_pre_simples  0.009003   0.005997  0.588126
# 9   LinearRegression_pre_simples     0.009   0.005739  0.391319
# 10        ElasticNet_grid_search  0.010207   0.005105   0.45295
# 11        ElasticNet_grid_search  0.009999    0.00615  0.573037
# 12        ElasticNet_grid_search  0.009999   0.004588  0.406099
# 13        ElasticNet_grid_search  0.009517   0.006017   0.58773
# 14        ElasticNet_grid_search  0.009765   0.006012  0.392837
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                    -64.006461                       -73.222493     0.004786
# 1                    -70.577936                       -80.043187     0.002999
# 2                    -59.829545                       -74.338597     0.003001
# 3                    -70.053929                       -82.047452        0.003
# 4                    -65.425655                       -76.315297     0.002997
# 5                    -42.980798                       -53.868349      0.02031
# 6                    -41.530714                        -51.57032     0.016126
# 7                    -46.702453                       -56.820458     0.014737
# 8                    -41.895672                       -52.650369        0.015
# 9                    -47.423856                       -58.318554     0.014739
# 10                   -42.987457                       -53.836373     0.015312
# 11                   -41.547094                       -51.610583     0.016149
# 12                   -46.754807                       -56.855605     0.014587
# 13                   -41.908988                       -52.675656     0.015535
# 14                   -47.335243                       -58.245772     0.015777

# %%
plot_comparar_metricas_modelos(df_resultados)
