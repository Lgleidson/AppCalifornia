# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from src.config import DADOS_LIMPOS
from src.auxiliares import dataframe_coeficientes
from src.graficos import (
    plot_coeficientes,
    plot_comparar_metricas_modelos,
    plot_residuos_estimador,
)
from src.models import (
    organiza_resultados,
    treinar_e_validar_modelo_regressao,
    grid_search_cv_regressor,
)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294117                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343676                  2.362768
#
#    bedrooms_per_room
# 0           0.146591
# 1           0.155797
# 2           0.260274
# 3           0.252679
# 4           0.203216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17564 non-null  float32
#  1   latitude                  17564 non-null  float32
#  2   housing_median_age        17564 non-null  int8
#  3   total_rooms               17564 non-null  int16
#  4   total_bedrooms            17564 non-null  int16
#  5   population                17564 non-null  int16
#  6   households                17564 non-null  int16
#  7   median_income             17564 non-null  float32
#  8   median_house_value        17564 non-null  int32
#  9   ocean_proximity           17564 non-null  category
#  10  median_income_cat         17564 non-null  int64
#  11  rooms_per_household       17564 non-null  float32
#  12  population_per_household  17564 non-null  float32
#  13  bedrooms_per_room         17564 non-null  float32
# dtypes: category(1), float32(6), int16(4), int32(1), int64(1), int8(1)
# memory usage: 789.3 KB

# %%
coluna_target = ["median_house_value"]

coluna_one_hot_encoder = ["ocean_proximity"]

coluna_ordinal_encoder = ["median_income_cat"]

# %%
preprocessamento = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories="auto"), coluna_ordinal_encoder),
        ("one_hot", OneHotEncoder(drop="first"), coluna_one_hot_encoder),
    ],
    remainder="passthrough",
)

# %%
X = df.drop(columns=coluna_target)
y = df[coluna_target]

# %%
X.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income ocean_proximity  median_income_cat  \
# 0         322         126         8.3252        NEAR BAY                  5
# 1        2401        1138         8.3014        NEAR BAY                  5
# 2        1206         595         2.0804        NEAR BAY                  2
# 3         697         264         2.1250        NEAR BAY                  2
# 4         990         419         1.9911        NEAR BAY                  2
#
#    rooms_per_household  population_per_household  bedrooms_per_room
# 0             6.984127                  2.555556           0.146591
# 1             6.238137                  2.109842           0.155797
# 2             4.294117                  2.026891           0.260274
# 3             4.242424                  2.640152           0.252679
# 4             5.343676                  2.362768           0.203216

# %%
y.head()
# Out:
#    median_house_value
# 0              452600
# 1              358500
# 2              226700
# 3              140000
# 4              158700

# %%
target_transformer = PowerTransformer()

regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_target": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": target_transformer,
    },
}

# %%
resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                       model  fit_time score_time   test_r2  \
# 0            DummyRegressor   0.01245    0.01295 -0.000081
# 1            DummyRegressor    0.0085   0.008974 -0.000146
# 2            DummyRegressor  0.005744    0.00914 -0.001737
# 3            DummyRegressor   0.00711   0.009287 -0.000101
# 4            DummyRegressor  0.004388   0.011931 -0.000114
# 5          LinearRegression   0.13757   0.019423  0.682162
# 6          LinearRegression  0.041488   0.022551   0.66999
# 7          LinearRegression  0.038092   0.020203  0.649247
# 8          LinearRegression  0.039809   0.019288  0.669873
# 9          LinearRegression  0.038551    0.01726  0.669023
# 10  LinearRegression_target  0.072831   0.017484  0.684232
# 11  LinearRegression_target    0.0721   0.017342  0.671042
# 12  LinearRegression_target   0.07041   0.019419  0.646094
# 13  LinearRegression_target   0.06819    0.01966  0.677544
# 14  LinearRegression_target   0.07128   0.018548  0.677014
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692       0.0254
# 1                 -75787.787194                    -95217.629397     0.017474
# 2                 -76753.598961                    -96253.253947     0.014884
# 3                 -76837.804811                    -95983.885799     0.016397
# 4                 -76617.245449                    -96182.764729     0.016319
# 5                 -39855.690921                    -54254.958115     0.156993
# 6                 -40272.565406                    -54695.230224      0.06404
# 7                 -42178.059246                    -56955.988686     0.058295
# 8                 -40806.492452                     -55146.31876     0.059096
# 9                 -40788.496555                    -55331.351171      0.05581
# 10                -38127.990089                     -54078.01827     0.090315
# 11                -38515.387176                    -54607.941381     0.089442
# 12                -40531.127371                    -57211.351363     0.089829
# 13                -38827.012941                    -54501.880328      0.08785
# 14                -38544.774193                    -54659.330513     0.089828

# %%
df_resultados.groupby("model").mean()
# Out:
#                          fit_time score_time   test_r2  \
# model
# DummyRegressor           0.007638   0.010456 -0.000436
# LinearRegression         0.059102   0.019745  0.668059
# LinearRegression_target  0.070962   0.018491  0.671185
#
#                         test_neg_mean_absolute_error  \
# model
# DummyRegressor                         -76702.495836
# LinearRegression                       -40780.260916
# LinearRegression_target                -38909.258354
#
#                         test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                             -95975.447913     0.018095
# LinearRegression                           -55276.769391     0.078847
# LinearRegression_target                    -55011.704371     0.089453

# %%
plot_comparar_metricas_modelos(df_resultados)

# %%
param_grid = {
    "transformer": [None, PowerTransformer(), QuantileTransformer(output_distribution="normal")]
}

# %%
grid_search = grid_search_cv_regressor(
    regressor=LinearRegression(),
    preprocessor=preprocessamento,
    target_transformer=target_transformer,
    param_grid=param_grid,
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(remainder='passthrough',
#                                                                                                transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity'])])),
#                                                                             ('reg',
#                                                                              LinearRegression())]),
#                                                   transformer=PowerTransformer()),
#              n_jobs=-1,
#              param_grid={'transformer': [None, PowerTransformer(),
#                                          QuantileTransformer(output_distribution='normal')]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(remainder='passthrough',
#                                                                                                transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity'])])),
#                                                                             ('reg',
#                                                                              LinearRegression())]),
#                                                   transformer=PowerTransformer()),
#              n_jobs=-1,
#              param_grid={'transformer': [None, PowerTransformer(),
#                                          QuantileTransformer(output_distribution='normal')]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'transformer': QuantileTransformer(output_distribution='normal')}

# %%
grid_search.best_score_
# Out:
# np.float64(-54417.152473170914)

# %%
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_["reg"].coef_,
    grid_search.best_estimator_.regressor_["preprocessor"].get_feature_names_out(),
)

coefs
# Out:
#                                      coeficiente
# one_hot__ocean_proximity_INLAND        -0.452676
# remainder__longitude                   -0.294966
# remainder__latitude                    -0.288190
# remainder__population_per_household    -0.280716
# one_hot__ocean_proximity_NEAR BAY      -0.201875
# one_hot__ocean_proximity_NEAR OCEAN    -0.058183
# remainder__total_bedrooms              -0.000233
# remainder__total_rooms                 -0.000060
# remainder__population                  -0.000036
# remainder__households                   0.000860
# remainder__housing_median_age           0.006669
# ordinal_encoder__median_income_cat      0.033547
# remainder__rooms_per_household          0.118269
# remainder__median_income                0.387737
# remainder__bedrooms_per_room            3.948688

# %%
plot_coeficientes(coefs)

# %%
regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_target_power": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": target_transformer,
    },
    "LinearRegression_target_quantile": {
        "preprocessor": grid_search.best_estimator_.regressor_["preprocessor"],
        "regressor": grid_search.best_estimator_.regressor_["reg"],
        "target_transformer": grid_search.best_estimator_.transformer_,
    },
}


resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                                model  fit_time score_time   test_r2  \
# 0                     DummyRegressor  0.011746   0.008981 -0.000081
# 1                     DummyRegressor  0.008326   0.003366 -0.000146
# 2                     DummyRegressor  0.007625   0.007558 -0.001737
# 3                     DummyRegressor  0.007171   0.007153 -0.000101
# 4                     DummyRegressor  0.005547   0.010216 -0.000114
# 5                   LinearRegression   0.03792     0.0198  0.682162
# 6                   LinearRegression  0.038439   0.017794   0.66999
# 7                   LinearRegression  0.035782   0.016201  0.649247
# 8                   LinearRegression  0.036174   0.017949  0.669873
# 9                   LinearRegression  0.036023   0.017691  0.669023
# 10     LinearRegression_target_power  0.068749   0.018129  0.684232
# 11     LinearRegression_target_power  0.065973   0.019855  0.671042
# 12     LinearRegression_target_power  0.066249   0.019787  0.646094
# 13     LinearRegression_target_power  0.066232   0.017833  0.677544
# 14     LinearRegression_target_power  0.064128   0.019737  0.677014
# 15  LinearRegression_target_quantile   0.04792    0.01821  0.691221
# 16  LinearRegression_target_quantile  0.047971    0.01762  0.677676
# 17  LinearRegression_target_quantile  0.048168   0.020241  0.653218
# 18  LinearRegression_target_quantile  0.048107   0.019728  0.683646
# 19  LinearRegression_target_quantile  0.050213   0.018286  0.682789
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.020727
# 1                 -75787.787194                    -95217.629397     0.011692
# 2                 -76753.598961                    -96253.253947     0.015182
# 3                 -76837.804811                    -95983.885799     0.014324
# 4                 -76617.245449                    -96182.764729     0.015764
# 5                 -39855.690921                    -54254.958115      0.05772
# 6                 -40272.565406                    -54695.230224     0.056233
# 7                 -42178.059246                    -56955.988686     0.051983
# 8                 -40806.492452                     -55146.31876     0.054123
# 9                 -40788.496555                    -55331.351171     0.053714
# 10                -38127.990089                     -54078.01827     0.086878
# 11                -38515.387176                    -54607.941381     0.085828
# 12                -40531.127371                    -57211.351363     0.086036
# 13                -38827.012941                    -54501.880328     0.084065
# 14                -38544.774193                    -54659.330513     0.083865
# 15                -37812.910436                    -53476.199943     0.066129
# 16                -38278.666733                    -54054.522701     0.065591
# 17                -40292.244657                     -56632.63629     0.068409
# 18                -38595.903159                    -53983.719882     0.067835
# 19                -38409.778684                    -54168.432799     0.068498

# %%
df_resultados.groupby("model").mean()
# Out:
#                                   fit_time score_time   test_r2  \
# model
# DummyRegressor                    0.008083   0.007455 -0.000436
# LinearRegression                  0.036868   0.017887  0.668059
# LinearRegression_target_power     0.066266   0.019068  0.671185
# LinearRegression_target_quantile  0.048476   0.018817   0.67771
#
#                                  test_neg_mean_absolute_error  \
# model
# DummyRegressor                                  -76702.495836
# LinearRegression                                -40780.260916
# LinearRegression_target_power                   -38909.258354
# LinearRegression_target_quantile                -38677.900734
#
#                                  test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                                      -95975.447913     0.015538
# LinearRegression                                    -55276.769391     0.054755
# LinearRegression_target_power                       -55011.704371     0.085335
# LinearRegression_target_quantile                    -54463.102323     0.067292

# %%
plot_comparar_metricas_modelos(df_resultados)
